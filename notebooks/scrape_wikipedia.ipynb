# %% [markdown]
# # Imports

# %% [markdown]
# Use this one

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Functions

# %%
def get_html_data(soup, html_tag, class_name, id): # returns the specific tag with class and id
    raw_html_data = soup.find(html_tag , attrs={'class': class_name, 'id': id})
    return raw_html_data

# %% [markdown]
# # Get the stock table

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br"
}

# %%
raw_stock_table_class = "wikitable sortable mw-collapsible sticky-header jquery-tablesorter mw-made-collapsible"
stock_table_class = raw_stock_table_class.split()
stock_table_id = "constituents"

raw_changes_class = "wikitable sortable jquery-tablesorter"
changes_class = raw_changes_class.split()
changes_id = "changes"

# %%
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies#Selected_changes_to_the_list_of_S&P_500_components"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# %% [markdown]
# # Filter data

# %% [markdown]
# ## Get tables from wikipedia

# %%
# import lxml
from io import StringIO

tables = pd.read_html(StringIO(str(soup)), flavor='lxml')

# %%
stock_list = tables[1]
stock_change_list = tables[2]

# %%
stock_list.to_csv("../../data/stock_lists/stock_list.csv")
stock_change_list.to_csv("../../data/stock_lists/stock_change_list.csv")

# %%
stock_change_list
# Out:
#          Effective Date  Added                                Removed  \
#          Effective Date Ticker                       Security  Ticker
# 0     November 28, 2025   SNDK                        Sandisk     IPG
# 1      November 4, 2025    NaN                            NaN     EMN
# 2      November 3, 2025      Q              Qnity Electronics     NaN
# 3      October 31, 2025    NaN                            NaN     KMX
# 4      October 30, 2025   SOLS    Solstice Advanced Materials     NaN
# ..                  ...    ...                            ...     ...
# 379   December 11, 1998   CPWR                      Compuware     SUN
# 380       June 17, 1997    CCR  Countrywide Credit Industries     USL
# 381  September 30, 1994    NCC                  National City     MCK
# 382        July 1, 1976    BUD                 Anheuser Busch     HNG
# 383        July 1, 1976    DIS        The Walt Disney Company     AYE
#
#                                                                       Reason
#                  Security                                             Reason
# 0       Interpublic Group  S&P 500 constituent Omnicom Group Inc. (OMC) i...
# 1    Eastman Chemical Co.                   Market capitalization change.[8]
# 2                     NaN  S&P 500 constituent Dupont de Nemours, Inc. sp...
# 3                  CarMax                   Market capitalization change.[8]
# 4                     NaN  S&P 500 and S&P 100 constituent Honeywell Inte...
# ..                    ...                                                ...
# 379            SunAmerica                     AIG purchased SunAmerica.[272]
# 380                USLife                          AIG acquired USLife.[273]
# 381              McKesson  McKesson sold PCS Health Services to Eli Lilly...
# 382   Houston Natural Gas  Major restructuring of S&P 500 to have fewer i...
# 383      Allegheny Energy  Major restructuring of S&P 500 to have fewer i...
#
# [384 rows x 6 columns]

# %%
stock_list
